# %%
import pandas as pd
import sqlalchemy

# %%
cliente = pd.read_excel ('07022023 (1).xltx')

# %%
cliente
# Out:
#            data  cod_loja  cod_produto                            descricao  \
# 0    2023-02-07         2         4411  CANJIQUINHA PACHA 500G
# 1    2023-02-07         2       104401  CANJIQUINHA PEREIRA 500G
# 2    2023-02-07         2       174992  PIPOCA MICRO PACHA NATURAL 100G
# 3    2023-02-07         2       175005  PIPOCA MICRO PACHA QUEIJO 100G
# 4    2023-02-07         2       361484  MILHO PIPOCA PACHA PREMIUM 500G
# ...         ...       ...          ...                                  ...
# 1684 2023-02-07         2       213226  TAPETE PANOSUL EMBORRACHADO 40X60M
# 1685 2023-02-07         2       227360  PASSADEIRA ARTESANAL UND
# 1686 2023-02-07         2       196048  FITA ADESIVA EMBALAGEM FINA 12X40
# 1687 2023-02-07         2         9928  BOBINA PICOTADA PLASTICO KG
# 1688 2023-02-07         2       193931  GLP BOTIJAO 13KG
#
#       qtde_vendas  valor_unitario  valor_total
# 0           1.000            2.69         2.69
# ...

# %%
engine = sqlalchemy.create_engine("postgresql://gestor02aws:gWxzF_xfxgestorsm@db-comercialoliveira.kikker.com.br:5432/kikker_production_comercialoliveira")

# %%
kikker = pd.read_sql("""select  sdm.movement_date as data,
		st.store_code as cod_loja,
        pd.code as cod_produto,
        pd.description AS descricao,
        round(sdm.actual_sales,3) as qtde_vendas,
        sdm.gross_sales_unit_price as valor_unitario,
        round(sdm.actual_sales * sdm.gross_sales_unit_price,2) as valor_total
from summarized_daily_movements as sdm
left join stores as st on (sdm.store_id = st.id)
left join products as pd on (sdm.product_id = pd.id)
--where sdm.business_group_id = '5ddca360-ae45-4fbe-a279-ab9da39f521c'
where sdm.movement_date between '2023-02-07' and '2023-02-07'
--and st.store_code = '113774'
and sdm.actual_sales <> 0
--AND pd.code <> 'None'
order by sdm.movement_date, pd.code;""", engine)

# %%
kikker
# Out:
#             data cod_loja cod_produto                     descricao  \
# 0     2023-02-07       02      000383       SACOLIXOPOKLIXO100LTSC5
# 1     2023-02-07       02      000451      REFRIANTARCTICA350MLLATA
# 2     2023-02-07       02      000482       OLEOCAPILARATALAIA120ML
# 3     2023-02-07       02      000512              PADPAORECHEADOKG
# 4     2023-02-07       02      000642        PADTORTAANIVERSSARIOKG
# ...          ...      ...         ...                           ...
# 1685  2023-02-07       02      361514    FAROFAPRONTAPACHABACON300G
# 1686  2023-02-07       02      361521              TAPIOCAPACHA500G
# 1687  2023-02-07       02      456562         GLADEAEROLAVANDA360ML
# 1688  2023-02-07       02      456647  MACSTAAMALIACOVOSGRAVATA500G
# 1689  2023-02-07       02      456715     MULTIUSOUAUDESENGLAV500ML
#
#       qtde_vendas  valor_unitario  valor_total
# 0           2.000            3.39         6.78
# 1           2.000            3.29         6.58
# ...

# %%
cliente.qtde_vendas=round(cliente.qtde_vendas,3)
cliente.valor_total=round(cliente.valor_total,2)
cliente.info()
#colocando a qtde vendas e valor total com valor maxino de decimais após a virgula
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1689 entries, 0 to 1688
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data            1689 non-null   datetime64[ns]
#  1   cod_loja        1689 non-null   int64
#  2   cod_produto     1689 non-null   int64
#  3   descricao       1689 non-null   object
#  4   qtde_vendas     1689 non-null   float64
#  5   valor_unitario  1689 non-null   float64
#  6   valor_total     1689 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 92.5+ KB

# %%
kikker.valor_total=round(kikker.valor_total,2)
kikker.qtde_vendas=round(kikker.qtde_vendas,3)
kikker.data=kikker.data.astype('datetime64')
kikker.cod_loja=kikker.cod_loja.astype('int')
kikker.cod_produto=kikker.cod_produto.astype('int')
kikker.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1690 entries, 0 to 1689
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data            1690 non-null   datetime64[ns]
#  1   cod_loja        1690 non-null   int64
#  2   cod_produto     1690 non-null   int64
#  3   descricao       1690 non-null   object
#  4   qtde_vendas     1690 non-null   float64
#  5   valor_unitario  1690 non-null   float64
#  6   valor_total     1690 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 92.5+ KB

# %%
t=pd.merge(kikker,cliente,how='outer',on=['data','cod_loja','cod_produto'])
#fazendo a junção das tabelas kikkes e cliente

# %%
t['dif_qtde']=t.qtde_vendas_x-t.qtde_vendas_y

# %%
t['dif_total']=t.valor_total_x-t.valor_total_y

# %%
t
# Out:
#            data  cod_loja  cod_produto                   descricao_x  \
# 0    2023-02-07         2          383       SACOLIXOPOKLIXO100LTSC5
# 1    2023-02-07         2          451      REFRIANTARCTICA350MLLATA
# 2    2023-02-07         2          482       OLEOCAPILARATALAIA120ML
# 3    2023-02-07         2          512              PADPAORECHEADOKG
# 4    2023-02-07         2          642        PADTORTAANIVERSSARIOKG
# ...         ...       ...          ...                           ...
# 1685 2023-02-07         2       361514    FAROFAPRONTAPACHABACON300G
# 1686 2023-02-07         2       361521              TAPIOCAPACHA500G
# 1687 2023-02-07         2       456562         GLADEAEROLAVANDA360ML
# 1688 2023-02-07         2       456647  MACSTAAMALIACOVOSGRAVATA500G
# 1689 2023-02-07         2       456715     MULTIUSOUAUDESENGLAV500ML
#
#       qtde_vendas_x  valor_unitario_x  valor_total_x  \
# 0             2.000              3.39           6.78
# ...

# %%
t=t[(t['dif_qtde']!=0)|(t['dif_total']!=0)|(t['dif_total'].isna())]

# %%
t.to_csv('validacao.csv',sep=';',index=False)
